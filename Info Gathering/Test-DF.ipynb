# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
path1 = "Resources/SGO-2021-01_Incident_Reports_ADS.csv"
path2 = "Resources/SGO-2021-01_Incident_Reports_ADAS2.csv"
path3 =

# %%
crash_data = pd.read_csv(path1)
crash_data.head()
# Out:
#     Report ID  Report Version               Reporting Entity     Report Type  \
# 0  30490-4473               1                     Beep, Inc.         Monthly
# 1  30531-4492               2  Transdev Alternative Services  Monthly Update
# 2  30531-4494               1  Transdev Alternative Services         Monthly
# 3  30531-4492               1  Transdev Alternative Services         Monthly
# 4  30270-4485               1                      Waymo LLC         Monthly
#
#    Report Month  Report Year Report Submission Date          VIN  \
# 0          12.0       2022.0                 Dec-22  1N9A1SAC6JS
# 1          11.0       2022.0                 Dec-22  SADHW2S16M1
# 2          11.0       2022.0                 Dec-22  SADHW2S19M1
# 3          11.0       2022.0                 Dec-22  SADHW2S16M1
# 4          11.0       2022.0                 Dec-22  SADHW2S19M1
#
#   VIN - Unknown Serial Number  ...  \
# 0                         NaN  ...
# 1                         NaN  ...
# 2                         NaN  ...
# 3                         NaN  ...
# 4                         NaN  ...
#
#                           Investigating Officer Name  \
# 0  [MAY CONTAIN PERSONALLY IDENTIFIABLE INFORMATION]
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Inv. Officer Name - Unknown Investigating Officer Phone  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
#    Inv. Officer Phone - Unknown Investigating Officer Email  \
# 0                             Y                         NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
#
#   Inv. Officer Email - Unknown  Within ODD? Within ODD? - CBI  \
# 0                            Y          Yes
# 1                                       Yes
# 2                                       Yes
# 3                                       Yes
# 4                                       Yes
#
#                                            Narrative Narrative - CBI?
# 0   On December [XXX], 2022, a Navya ARMA shuttle...              NaN
# 1  Corrected the latitude and longitude. Nothing ...
# 2  On November [XXX], 2022 at 9:34 AM PST a Waymo...
# 3  On November [XXX], 2022 at 4:30 PM PST a Waymo...
# 4  On November [XXX], 2022 at 9:34 AM PST a Waymo...
#
# [5 rows x 122 columns]

# %%
tesla_data = pd.read_csv(path2)
tesla_data.head()
# Out:
#     Report ID  Report Version                          Reporting Entity  \
# 0  13781-4354               2                               Tesla, Inc.
# 1  13781-4353               2                               Tesla, Inc.
# 2    540-4483               1                       General Motors, LLC
# 3  13781-4479               1                               Tesla, Inc.
# 4   1306-4287               3  Toyota Motor Engineering & Manufacturing
#
#       Report Type  Report Month  Report Year Report Submission Date  \
# 0   10-Day Update           NaN          NaN                 Dec-22
# 1   10-Day Update           NaN          NaN                 Dec-22
# 2           1-Day           NaN          NaN                 Dec-22
# 3           1-Day           NaN          NaN                 Dec-22
# 4  Monthly Update          11.0       2022.0                 Dec-22
#
#            VIN VIN - Unknown Serial Number  ... Investigating Officer Name  \
# 0  5YJYGDEE7LF                         NaN  ...                        NaN
# 1  5YJ3E1EB8KF                         NaN  ...                        NaN
# 2  1G6KG5RS1JU                         NaN  ...                        NaN
# 3  5YJXCBE2XJF                         NaN  ...                        NaN
# 4  JTJHGKFA1N2                         NaN  ...                        NaN
#
#   Inv. Officer Name - Unknown Investigating Officer Phone  \
# 0                           Y                         NaN
# 1                           Y                         NaN
# 2                           Y                         NaN
# 3                           Y                         NaN
# 4                           Y                         NaN
#
#    Inv. Officer Phone - Unknown Investigating Officer Email  \
# 0                             Y                         NaN
# 1                             Y                         NaN
# 2                             Y                         NaN
# 3                             Y                         NaN
# 4                             Y                         NaN
#
#   Inv. Officer Email - Unknown  \
# 0                            Y
# 1                            Y
# 2                            Y
# 3                            Y
# 4                            Y
#
#                                          Within ODD? Within ODD? - CBI  \
# 0  [REDACTED, MAY CONTAIN CONFIDENTIAL BUSINESS I...                 Y
# 1  [REDACTED, MAY CONTAIN CONFIDENTIAL BUSINESS I...                 Y
# 2                                                Yes
# 3  [REDACTED, MAY CONTAIN CONFIDENTIAL BUSINESS I...                 Y
# 4                             Unknown, see Narrative
#
#                                            Narrative Narrative - CBI?
# 0  [REDACTED, MAY CONTAIN CONFIDENTIAL BUSINESS I...                Y
# 1  [REDACTED, MAY CONTAIN CONFIDENTIAL BUSINESS I...                Y
# 2  The subject vehicle, a 2018 Cadillac CT6, was ...
# 3  [REDACTED, MAY CONTAIN CONFIDENTIAL BUSINESS I...                Y
# 4  The entries in this report are based on unconf...
#
# [5 rows x 122 columns]

# %%
clean_crash1 = crash_data.loc[:, ["Make", "Model","Model Year","Driver / Operator Type", "Incident Date", 
                                      "Incident Time (24:00)","City", "State", "Roadway Type", "Roadway Surface", 
                                     "Roadway Description", "Crash With", "Highest Injury Severity", "CP Any Air Bags Deployed?"]]
clean_crash1.head()
# Out:
#      Make   Model  Model Year          Driver / Operator Type Incident Date  \
# 0   Navya    ARMA      2018.0  In-Vehicle (Commercial / Test)        Dec-22
# 1  Jaguar  I-Pace      2021.0  In-Vehicle (Commercial / Test)        Nov-22
# 2  Jaguar  I-Pace      2021.0  In-Vehicle (Commercial / Test)        Nov-22
# 3  Jaguar  I-Pace      2021.0  In-Vehicle (Commercial / Test)        Nov-22
# 4  Jaguar  I-Pace      2021.0  In-Vehicle (Commercial / Test)        Nov-22
#
#   Incident Time (24:00)              City State  Roadway Type Roadway Surface  \
# 0                 17:53  Port Saint Lucie   FL         Street             Dry
# 1                 16:30     San Francisco   CA         Street             Dry
# 2                  9:34     San Francisco   CA   Intersection             Wet
# 3                 16:30     San Francisco   CA         Street             Dry
# 4                  9:34     San Francisco   CA   Intersection             Wet
#
#      Roadway Description     Crash With Highest Injury Severity  \
# 0  No Unusual Conditions  Passenger Car    No Injuries Reported
# 1  No Unusual Conditions            SUV    No Injuries Reported
# 2  No Unusual Conditions  Passenger Car    No Injuries Reported
# 3  No Unusual Conditions            SUV    No Injuries Reported
# 4  No Unusual Conditions  Passenger Car    No Injuries Reported
#
#   CP Any Air Bags Deployed?
# 0                        No
# 1                        No
# 2                   Unknown
# 3                        No
# 4                   Unknown

# %%
clean_crash2 = tesla_data.loc[:, ["Make", "Model","Model Year","Driver / Operator Type", "Incident Date", 
                                      "Incident Time (24:00)","City", "State", "Roadway Type", "Roadway Surface", 
                                     "Roadway Description", "Crash With", "Highest Injury Severity", "CP Any Air Bags Deployed?"]]
clean_crash2.head()
# Out:
#        Make    Model  Model Year Driver / Operator Type Incident Date  \
# 0     Tesla  Model Y      2020.0               Consumer        Dec-22
# 1     Tesla  Model 3      2019.0               Consumer        Dec-22
# 2  Cadillac      CT6      2018.0               Consumer        Dec-22
# 3     Tesla  Model X      2018.0               Consumer        Dec-22
# 4     Lexus  RX450hL      2022.0               Consumer        Nov-22
#
#   Incident Time (24:00)           City State       Roadway Type  \
# 0                  5:31  Mercer Island   WA             Unknown
# 1                  9:00         Tacoma   WA   Highway / Freeway
# 2                 16:27   Millersville   MA   Highway / Freeway
# 3                 18:00      Inglewood   CA   Highway / Freeway
# 4                  3:28       McDonald   NC   Highway / Freeway
#
#   Roadway Surface    Roadway Description          Crash With  \
# 0         Unknown                Unknown             Unknown
# 1         Unknown                Unknown  Other Fixed Object
# 2             Dry  No Unusual Conditions                 SUV
# 3         Unknown                Unknown             Unknown
# 4         Unknown                Unknown  Other Fixed Object
#
#   Highest Injury Severity CP Any Air Bags Deployed?
# 0                 Unknown                   Unknown
# 1                 Unknown                       NaN
# 2    No Injuries Reported                   Unknown
# 3                 Unknown                   Unknown
# 4                 Unknown                       NaN

# %%
merge_df = pd.concat([clean_crash1, clean_crash2], axis=0)
merge_df
# Out:
#         Make         Model  Model Year          Driver / Operator Type  \
# 0      Navya          ARMA      2018.0  In-Vehicle (Commercial / Test)
# 1     Jaguar        I-Pace      2021.0  In-Vehicle (Commercial / Test)
# 2     Jaguar        I-Pace      2021.0  In-Vehicle (Commercial / Test)
# 3     Jaguar        I-Pace      2021.0  In-Vehicle (Commercial / Test)
# 4     Jaguar        I-Pace      2021.0  In-Vehicle (Commercial / Test)
# ...      ...           ...         ...                             ...
# 1489   Tesla       Model Y      2021.0                        Consumer
# 1490   Tesla       Model Y      2020.0                        Consumer
# 1491   Tesla       Model 3      2020.0                        Consumer
# 1492   Tesla       Model 3      2021.0                        Consumer
# 1493     BMW  X5 xDrive40i      2019.0                        Consumer
#
#      Incident Date Incident Time (24:00)              City State  \
# 0           Dec-22                 17:53  Port Saint Lucie   FL
# 1           Nov-22                 16:30     San Francisco   CA
# 2           Nov-22                  9:34     San Francisco   CA
# 3           Nov-22                 16:30     San Francisco   CA
# 4           Nov-22                  9:34     San Francisco   CA
# ...            ...                   ...               ...   ...
# 1489        Jul-21                  4:09               NaN   NY
# 1490        Jun-21                  1:28        Santa Cruz   CA
# 1491        Jul-21                  0:35       San Antonio   TX
# 1492        Jul-21                  8:17     Mountain View   CA
# 1493        Jul-21                  0:00    St. Petersburg   FL
#
#            Roadway Type Roadway Surface    Roadway Description  \
# 0                Street             Dry  No Unusual Conditions
# 1                Street             Dry  No Unusual Conditions
# 2          Intersection             Wet  No Unusual Conditions
# 3                Street             Dry  No Unusual Conditions
# 4          Intersection             Wet  No Unusual Conditions
# ...                 ...             ...                    ...
# 1489            Unknown         Unknown                Unknown
# 1490            Unknown         Unknown                Unknown
# 1491            Unknown         Unknown                Unknown
# 1492            Unknown         Unknown                Unknown
# 1493  Highway / Freeway         Unknown                Unknown
#
#                     Crash With Highest Injury Severity  \
# 0                Passenger Car    No Injuries Reported
# 1                          SUV    No Injuries Reported
# 2                Passenger Car    No Injuries Reported
# 3                          SUV    No Injuries Reported
# 4                Passenger Car    No Injuries Reported
# ...                        ...                     ...
# 1489  Non-Motorist: Pedestrian                Fatality
# 1490                   Unknown                 Unknown
# 1491                   Unknown                 Unknown
# 1492                   Unknown                 Unknown
# 1493      Other, see Narrative                   Minor
#
#      CP Any Air Bags Deployed?
# 0                           No
# 1                           No
# 2                      Unknown
# 3                           No
# 4                      Unknown
# ...                        ...
# 1489                   Unknown
# 1490                   Unknown
# 1491                   Unknown
# 1492                   Unknown
# 1493            Not Applicable
#
# [1990 rows x 14 columns]
